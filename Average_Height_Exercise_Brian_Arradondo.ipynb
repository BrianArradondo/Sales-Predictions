# %% [markdown]
# <a href="https://colab.research.google.com/github/BrianArradondo/AI-predictions/blob/main/Average_Height_Exercise_Brian_Arradondo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries
# - Average Height Exercise
#  - Week 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Imports loaded and drive mounted

# %% [markdown]
# # Loading the Data

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/athleteEventsNoPersonal.csv")

# %%
df.describe() # this line of code tells me the numerical statistics of the dataframe
# Out:
#                   ID           Age        Height          Year
# count   40616.000000  39143.000000  31615.000000  40616.000000
# mean    68140.888738     25.619498    175.381117   1978.653240
# std     38830.405762      6.494926     10.561791     29.850461
# min         5.000000     11.000000    135.000000   1896.000000
# 25%     34661.750000     21.000000    168.000000   1960.000000
# 50%     68016.500000     25.000000    175.000000   1988.000000
# 75%    101475.000000     28.000000    183.000000   2004.000000
# max    135571.000000     74.000000    221.000000   2016.000000

# %% [markdown]
# ## Inspect the Data

# %%
df.head() # this line of code allows me a rapid way to check and confirm my data is what was expected
# Out:
#    ID   Age  Height         Team  NOC        Games  Year  Season         City  \
# 0   5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 1   5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 2   5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 3   5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 4   5  27.0   185.0  Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
#
#            Sport                               Event Medal
# 0  Speed Skating    Speed Skating Women's 500 metres   NaN
# 1  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 2  Speed Skating    Speed Skating Women's 500 metres   NaN
# 3  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 4  Speed Skating    Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ##Shape()

# %%
df.shape # this line of code tells me how many rows and how many columns are in this dataset
print(f"There are are {df.shape[0]} rows, and {df.shape[1]} columns.")# this says there are 40,616 rows and 12 columns in this dataframe
# Out:
# There are are 40616 rows, and 12 columns.

# %% [markdown]
# ### How many rows?
# ### How many columns?

# %%
df.info() # This code is set up to tell me what the data looks like and identify which columns have missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40616 entries, 0 to 40615
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      40616 non-null  int64
#  1   Age     39143 non-null  float64
#  2   Height  31615 non-null  float64
#  3   Team    40616 non-null  object
#  4   NOC     40616 non-null  object
#  5   Games   40616 non-null  object
#  6   Year    40616 non-null  int64
#  7   Season  40616 non-null  object
#  8   City    40616 non-null  object
#  9   Sport   40616 non-null  object
#  10  Event   40616 non-null  object
#  11  Medal   5917 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 3.7+ MB

# %%
df.isna().sum() # this line of code tells me the sum of the missing values in each column
# Out:
# ID            0
# Age        1473
# Height     9001
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     34699
# dtype: int64

# %%
df.groupby("City").sum() # how many entries correspond to the city of London
# Out:
#                                ID      Age    Height     Year
# City
# Albertville              38033300  13011.0   76762.0  1085640
# Amsterdam                52114964  19373.0   23431.0  1459496
# Antwerpen                41258419  14931.0   15442.0  1238400
# Athina                  158004223  56367.0  361192.0  4626614
# Atlanta                 141283199  50289.0  312930.0  4065852
# Barcelona               134423131  47640.0  283718.0  3930216
# Beijing                 139762629  53452.0  359852.0  4128448
# Berlin                   59899376  24958.0   29966.0  1755952
# Calgary                  26246439   9069.0   51164.0   781284
# Chamonix                  5272623   1796.0    3062.0   151996
# Cortina d'Ampezzo        15017617   5298.0   10510.0   408804
# Garmisch-Partenkirchen    8466132   3267.0    4444.0   263296
# Grenoble                 20444693   6933.0   48312.0   572688
# Helsinki                 92155654  32375.0   52743.0  2547360
# ...

# %%
london = df[df["City"] == "London"] # This block of code helps to create a filter for everything that equals the city of London and a dataframe that captures that info and renames it london
london
len(london) # this line of code will tell us the length of the rows associated with London
# Out:
# 3370

# %%
print(f"There are {len(london)} number of entries that correspond to the city of London") # this f string will print my summary on the number of entries related to London
# Out:
# There are 3370 number of entries that correspond to the city of London

# %%
df["Age"].min() # This line of code returns the youngest athlete in our sample data
# Out:
# 11.0

# %%
Tugdudes = df["Sport"] == "Tug-Of-War"
Tugdudes
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40611    False
# 40612    False
# 40613    False
# 40614    False
# 40615    False
# Name: Sport, Length: 40616, dtype: bool

# %%
Tugwhat = df[Tugdudes] # this line uses the dataframe I created that encompasses everyone that
Tugwhat
# Out:
#            ID   Age  Height                                   Team  NOC  \
# 2330     8484   NaN     NaN                  Racing Club de France  FRA
# 2628     9508  29.0     NaN                            Netherlands  NED
# 4148    14765   NaN     NaN    St. Louis Southwest Turnverein #1-2  USA
# 4823    16935  36.0     NaN                Liverpool Police Team-2  GBR
# 5072    17931  30.0     NaN                          Great Britain  GBR
# 5222    18465  34.0     NaN                                  Italy  ITA
# 8644    29549  24.0   182.0                                Germany  GER
# 9124    31220  34.0     NaN  K Division Metropolitan Police Team-3  GBR
# 10023   34205  22.0     NaN                                 Sweden  SWE
# 12681   43105  23.0     NaN                                 Sweden  SWE
# 13015   44087  29.0   182.0                                 Sweden  SWE
# 15142   51449  29.0     NaN                          Great Britain  GBR
# ...

# %%
Tugwhat["Team"].value_counts()["Sweden"] # This line of code shows the number of athletes from the team Sweden who participated in Tug of War
# Out:
# 6

# %%
winners =  df["Medal"] == "Gold" # This creates a filter that yields the category of Medal that features a Gold Medal
winners
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40611    False
# 40612    False
# 40613    False
# 40614    False
# 40615    False
# Name: Medal, Length: 40616, dtype: bool

# %%
winningest = df[winners] # this line of code creates a dataframe
winningest
# Out:
#            ID   Age  Height           Team  NOC        Games  Year  Season  \
# 26         42  25.0     NaN         Taifun  NOR  1912 Summer  1912  Summer
# 109       351  23.0   202.0  United States  USA  2000 Summer  2000  Summer
# 116       367  28.0   175.0          Japan  JPN  1994 Winter  1994  Winter
# 171       619  20.0   170.0   Soviet Union  URS  1980 Summer  1980  Summer
# 265       962  20.0     NaN  United States  USA  1952 Summer  1952  Summer
# ...       ...   ...     ...            ...  ...          ...   ...     ...
# 40500  135269  24.0   158.0          China  CHN  2012 Summer  2012  Summer
# 40501  135269  24.0   158.0          China  CHN  2012 Summer  2012  Summer
# 40534  135331  22.0   182.0   Soviet Union  URS  1980 Summer  1980  Summer
# 40592  135520  28.0   167.0        Germany  GER  2004 Summer  2004  Summer
# 40604  135553  21.0   168.0   Soviet Union  URS  1952 Summer  1952  Summer
#
# ...

# %%
impressed = winningest["Age"]>40 # this is one way to get the result of how many athletes over the age of 40 recieved gold medals by applying the over age 40 filter to the df I created of who won gold medals
impressed
yougoyall = winningest[impressed]
yougoyall
# Out:
#            ID   Age  Height                Team  NOC        Games  Year  \
# 740      2735  41.0   168.0              Russia  RUS  2000 Summer  2000
# 1103     4029  46.0     NaN           Argentina  ARG  1936 Summer  1936
# 1421     4993  41.0   180.0             Mosk II  NOR  1920 Summer  1920
# 3040    10769  49.0   180.0          White Lady  DEN  1964 Summer  1964
# 3270    11617  44.0     NaN             Heroine  GBR  1908 Summer  1908
# ...       ...   ...     ...                 ...  ...          ...   ...
# 38916  130271  43.0     NaN            Heira II  NOR  1920 Summer  1920
# 38952  130381  42.0   167.0       United States  USA  1972 Summer  1972
# 39193  130936  56.0     NaN       United States  USA  1908 Summer  1908
# 39197  130936  60.0     NaN       United States  USA  1912 Summer  1912
# 39365  131533  58.0     NaN  Cincinnati Archers  USA  1904 Summer  1904
#
#        Season       City             Sport  \
# 740    Summer     Sydney          Shooting
# ...

# %%
ancientness = df["Age"]>40 # 
ancientness
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40611    False
# 40612    False
# 40613    False
# 40614    False
# 40615    False
# Name: Age, Length: 40616, dtype: bool

# %%
oldies = df[ancientness] # This line of code creates a dataframe that yields all athletes above age 40
oldies
# Out:
#            ID   Age  Height             Team  NOC        Games  Year  Season  \
# 122       389  45.0     NaN          Germany  GER  1928 Summer  1928  Summer
# 123       389  45.0     NaN          Germany  GER  1928 Summer  1928  Summer
# 131       432  42.0   180.0    Cote d'Ivoire  CIV  2008 Summer  2008  Summer
# 132       432  42.0   180.0    Cote d'Ivoire  CIV  2008 Summer  2008  Summer
# 186       677  55.0     NaN           France  FRA  1924 Summer  1924  Summer
# ...       ...   ...     ...              ...  ...          ...   ...     ...
# 40116  134046  41.0     NaN           Mexico  MEX  1928 Summer  1928  Summer
# 40117  134046  41.0     NaN           Mexico  MEX  1928 Summer  1928  Summer
# 40118  134046  41.0     NaN           Mexico  MEX  1928 Summer  1928  Summer
# 40119  134046  45.0     NaN           Mexico  MEX  1932 Summer  1932  Summer
# 40161  134204  46.0   172.0  Maid of Lebanon  LIB  1960 Summer  1960  Summer
#
#               City             Sport  \
# ...

# %%
admiration = df[ancientness & winners] # applying these two filters to the original df yields athletes over age 40 who received gold medals
admiration
# Out:
#            ID   Age  Height                Team  NOC        Games  Year  \
# 740      2735  41.0   168.0              Russia  RUS  2000 Summer  2000
# 1103     4029  46.0     NaN           Argentina  ARG  1936 Summer  1936
# 1421     4993  41.0   180.0             Mosk II  NOR  1920 Summer  1920
# 3040    10769  49.0   180.0          White Lady  DEN  1964 Summer  1964
# 3270    11617  44.0     NaN             Heroine  GBR  1908 Summer  1908
# ...       ...   ...     ...                 ...  ...          ...   ...
# 38916  130271  43.0     NaN            Heira II  NOR  1920 Summer  1920
# 38952  130381  42.0   167.0       United States  USA  1972 Summer  1972
# 39193  130936  56.0     NaN       United States  USA  1908 Summer  1908
# 39197  130936  60.0     NaN       United States  USA  1912 Summer  1912
# 39365  131533  58.0     NaN  Cincinnati Archers  USA  1904 Summer  1904
#
#        Season       City             Sport  \
# 740    Summer     Sydney          Shooting
# ...

# %%
tallness_df = df.groupby("Height") # this line of code creates a filter that is grouped by height
tallness_df

# %%
tallness_df.head()
# Out:
#            ID   Age  Height            Team  NOC        Games  Year  Season  \
# 0           5  21.0   185.0     Netherlands  NED  1988 Winter  1988  Winter
# 1           5  21.0   185.0     Netherlands  NED  1988 Winter  1988  Winter
# 2           5  25.0   185.0     Netherlands  NED  1992 Winter  1992  Winter
# 3           5  25.0   185.0     Netherlands  NED  1992 Winter  1992  Winter
# 4           5  27.0   185.0     Netherlands  NED  1994 Winter  1994  Winter
# ...       ...   ...     ...             ...  ...          ...   ...     ...
# 33451  111572  26.0   214.0  Czechoslovakia  TCH  1980 Summer  1980  Summer
# 36627  122221  24.0   209.0          Greece  GRE  2004 Summer  2004  Summer
# 36628  122221  28.0   209.0          Greece  GRE  2008 Summer  2008  Summer
# 37222  124247  24.0   209.0     Netherlands  NED  1996 Summer  1996  Summer
# 38765  129649  21.0   214.0          Canada  CAN  1984 Summer  1984  Summer
#
# ...

# %%
shorty = tallness_df.mean()
shorty
# Out:
#                    ID        Age         Year
# Height
# 135.0    43341.500000  14.000000  1980.000000
# 136.0   109593.000000  16.000000  1996.000000
# 139.0     4272.000000  14.000000  1972.000000
# 140.0    59483.833333  18.888889  1990.444444
# 142.0   100797.000000  15.500000  1922.000000
# ...               ...        ...          ...
# 214.0   120610.500000  23.500000  1982.000000
# 215.0    38960.000000  30.000000  2010.000000
# 219.0    83657.000000  23.000000  2012.000000
# 220.0    91087.000000  31.000000  1988.000000
# 221.0     9407.000000  29.000000  1992.000000
#
# [81 rows x 3 columns]

# %%
df["Height"].mean() # this line of code tells me that average height from all columns in the height column
# Out:
# 175.3811165585956

# %%
df.groupby(["Height","Event"]).mean() # This line of groupby code yields me the results of the average of Height by Event
# Out:
#                                                        ID   Age    Year
# Height Event
# 135.0  Gymnastics Women's Balance Beam            43341.5  14.0  1980.0
#        Gymnastics Women's Floor Exercise          43341.5  14.0  1980.0
#        Gymnastics Women's Horse Vault             43341.5  14.0  1980.0
#        Gymnastics Women's Individual All-Around   43341.5  14.0  1980.0
#        Gymnastics Women's Team All-Around         43341.5  14.0  1980.0
# ...                                                   ...   ...     ...
# 214.0  Basketball Men's Basketball               120610.5  23.5  1982.0
# 215.0  Basketball Men's Basketball                38960.0  30.0  2010.0
# 219.0  Volleyball Men's Volleyball                83657.0  23.0  2012.0
# 220.0  Basketball Men's Basketball                91087.0  31.0  1988.0
# 221.0  Basketball Men's Basketball                 9407.0  29.0  1992.0
#
# [8454 rows x 3 columns]
